# %%
import pandas as pd
import matplotlib
import seaborn as sns
import numpy as np
matplotlib.rcParams["figure.dpi"] = 400

# %%
finalData = pd.read_csv('/project/hackathon/hackers06/shared/finalDatafromAkshay/FinalData.csv')
uds = pd.read_csv('/project/hackathon/hackers06/shared/finalDatafromAkshay/FinalData3Class.csv')

# %%
uds['log_onset'] = np.log(uds['ONSET_DAYS'])
# Out:
# /cm/shared/apps/python/3.7.x-anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
onset_plot = sns.scatterplot(x='ONSET_DAYS', y='ACTUAL_LOS', hue='y_actual', data=uds)
log_onset_plot = sns.scatterplot(x='log_onset', y='ACTUAL_LOS', hue='y_actual', data=uds)

# %%
# Out:
# array([ 31,  49, 346,   9,   7,  27,   3,  34,   4,  24,   1, 183,  69,
#         14,   8,   2,   6,  33,  23,  15, 100,  38,  12,  29,  28,  10,
#         73,  17,  26,  39,  18,  13,  16,   5,  19, 140, 143,  52,  20,
#         30,  11, 116, 101,  21, 151, 105, 167,  93, 103,  40, 172,  65,
#        255,  54,  42, 125,  32,  45,   0,  64, 138, 144,  36,  56,  68,
#        357,  37, 230, 135,  75, 145,  82,  22,  81,  48,  87,  25,  95,
#        110,  78,  63,  59,  51, 111,  55,  67, 198,  58, 300, 119,  94,
#        176,  47,  92, 193, 106, 322,  61,  35, 240, 108,  41,  44, 137,
#         70,  62, 153, 136, 163, 208, 270, 202,  50, 366, 239,  46, 122,
#        102, 139,  97,  66, 309,  43, 245,  80, 252,  96, 279,  53, 201,
#         84, 131,  60, 302, 310, 177,  57,  99, 107,  83, 121, 187, 124,
#         90, 155, 126,  74, 112, 118, 292,  76,  79, 142, 150,  91, 164,
#        209, 175,  85, 132, 133, 327, 247, 320, 212,  77, 104,  71, 360,
# ...

# %%
# Out:
# 0.10352187833511206

# %%
# Out:
# 1874

# %%
# >0 <= 7 low
# >7 <= 21 medium
# > 21 <= 60 high
# >60 very high

# %%
# Out:
#       ACTUAL_LOS  ADM_IMPAIR_CODE  \
# 0             43           1.1000
# 1              6          16.0000
# 2             32           4.1212
# 3              5           2.1000
# 4             29           4.1110
# 5             31           4.2110
# 6              8           3.9000
# 7             20          11.0000
# 8             18          16.0000
# 9              8           5.4000
# 10            31           3.8000
# 11            19           1.2000
# 12            13           3.8000
# 13            12           2.1000
# 14            19           3.8000
# 15            17          10.9000
# 16             3           8.1100
# 17             7           4.1212
# 18            11           1.1000
# 19            15           1.2000
# 20            20           1.1000
# 21            16           8.1100
# 22            10           1.2000
# 23            10           3.3000
# 24             4           2.1000
# 25            15           2.2200
# ...

# %%
def getCat(x):
    if x > 0 and x <= 7:
        return 'LOW'
    elif x > 7 and x <= 21:
        return 'MEDIUM'
    elif x > 21 and x <= 60:
        return 'HIGH'
    else:
        return 'VERY HIGH'
finalData['y_actual'] = finalData['ONSET_DAYS'].apply(lambda x: getCat(x))

# %%
# finalData.to_csv('/project/hackathon/hackers06/shared/finalDatafromAkshay/FinalData.csv')

# %%
onset_plot.get_figure().savefig('onset_plot.png', dpi=400)

# %%
log_onset_plot.get_figure().savefig('log_onset_plot.png', dpi=400)

# %%
ls
# Out:
# Finding bins.ipynb            README.md                     model-building/
# KyleChesney/                  data-assimilation/            onset_plot.png
# LICENSE                       dhanushu-code_group_mapping/  plots/
# LisaShen-data_preprocessing/  mayukh-assimilating-data/

# %%
df = pd.read_csv('./data-assimilation/modelData.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889 entries, 0 to 1888
# Data columns (total 7 columns):
# IHAR                        1889 non-null int64
# MEDICARE_FEE_FOR_SERVICE    1889 non-null int64
# COMMERCIAL_AND_ADVANTAGE    1889 non-null int64
# AGENCY                      1889 non-null int64
# HEMISPHERIC_STROKE          1889 non-null int64
# EXP_LOS                     1889 non-null int64
# y_actual                    1889 non-null object
# dtypes: int64(6), object(1)
# memory usage: 103.4+ KB

# %%
color_pal = sns.color_palette("colorblind", 3).as_hex()
colors = ','.join(color_pal)

# %%
p = sns.scatterplot(x='log_onset', y='ACTUAL_LOS', hue='y_actual', data=uds, palette=color_pal)
p.set(xlabel="LOG ONSET", ylabel="ACTUAL LOS")
p.get_figure().savefig('log_onset_cb', dpi=400)

# %%
p = sns.scatterplot(x='ONSET_DAYS', y='ACTUAL_LOS', hue='y_actual', data=uds, palette=color_pal )
p.set(xlabel="ONSET DAYS", ylabel="ACTUAL LOS")
p.get_figure().savefig('onset', dpi=400)

# %%
color_pal = sns.color_palette("colorblind", 4).as_hex()
colors = ','.join(color_pal)

# %%
finalData['log_onset'] = np.log(finalData['ONSET_DAYS'])
# Out:
# /cm/shared/apps/python/3.7.x-anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
p = sns.scatterplot(x='log_onset', y='ACTUAL_LOS', hue='y_actual', data=finalData, palette=color_pal)
p.set(xlabel="ONSET DAYS", ylabel="ACTUAL LOS")
p.get_figure().savefig('log_onset_4class_cb.png', dpi=400)

# %%
p = sns.scatterplot(x='ONSET_DAYS', y='ACTUAL_LOS', hue='y_actual', data=finalData, palette=color_pal)
p.set(xlabel="ONSET DAYS", ylabel="ACTUAL LOS")
p.get_figure().savefig('onset_4class_cb.png', dpi=400)
